# %% [markdown]
# # Emission By Cars
#
# The Data set downloaded contains various information about a set of cars that were manufactured with set of factory parameters like cylinder size, number of cylinders, fuel consumption, Carbon dioxide emissions etc.
# A brief data analysis of the data set is done in this project

# %% [markdown]
# ## Data Preparation and Cleaning
#
# Loaded the dataset into a data frame using Pandas
# Handle missing, incorrect and invalid data
# Explored the number of rows & columns, ranges of values etc.

# %%
import os
os.chdir('/home/jovyan')

# %%
import pandas as pd
emission_df= pd.read_csv('Sample.csv')
emission_df
# Out:
#      MODEL   MAKE              MODEL.1             VEHICLE CLASS  ENGINE_SIZE  \
# 0     2001  ACURA                1.7EL                   COMPACT          1.7
# 1     2001  ACURA                1.7EL                   COMPACT          1.7
# 2     2001  ACURA                3.2CL                   COMPACT          3.2
# 3     2001  ACURA                3.2TL                  MID-SIZE          3.2
# 4     2001  ACURA                3.5RL                  MID-SIZE          3.5
# ..     ...    ...                  ...                       ...          ...
# 674   2001  VOLVO   V70 T5 WAGON TURBO  STATION WAGON - MID-SIZE          2.3
# 675   2001  VOLVO            V70 WAGON  STATION WAGON - MID-SIZE          2.4
# 676   2001  VOLVO            V70 WAGON  STATION WAGON - MID-SIZE          2.4
# 677   2001  VOLVO  V70 WAGON AWD TURBO  STATION WAGON - MID-SIZE          2.4
# 678   2001  VOLVO     V70 XC AWD TURBO                       SUV          2.4
#
# ...

# %%
emission_df.isna().sample(50)
# Out:
#      MODEL   MAKE  MODEL.1  VEHICLE CLASS  ENGINE_SIZE  CYLINDERS  \
# 97   False  False    False          False        False      False
# 284  False  False    False          False        False      False
# 261  False  False    False          False        False      False
# 545  False  False    False          False        False      False
# 476  False  False    False          False        False      False
# 46   False  False    False          False        False      False
# 615  False  False    False          False        False      False
# 431  False  False    False          False        False      False
# 341  False  False    False          False        False      False
# 484  False  False    False          False        False      False
# 305  False  False    False          False        False      False
# 186  False  False    False          False        False      False
# 567  False  False    False          False        False      False
# ...

# %%
emission_df.describe()
# Out:
#         MODEL  ENGINE_SIZE   CYLINDERS  FUEL_CONSUMPTION*  Unnamed: 9  \
# count   679.0   679.000000  679.000000         679.000000  679.000000
# mean   2001.0     3.252577    5.798233          14.591900   10.613844
# std       0.0     1.203751    1.531073           3.025654    2.357724
# min    2001.0     1.000000    3.000000           4.900000    4.000000
# 25%    2001.0     2.200000    4.000000          12.700000    9.000000
# 50%    2001.0     3.000000    6.000000          14.300000   10.100000
# 75%    2001.0     4.200000    6.000000          16.650000   12.500000
# max    2001.0     8.000000   12.000000          23.200000   18.000000
#
#        Unnamed: 10  Unnamed: 11  CO2_EMISSIONS
# count   679.000000   679.000000     679.000000
# mean     12.802798    23.107511     293.656848
# std       2.685590     5.308083      60.372456
# min       4.500000    14.000000     104.000000
# 25%      11.000000    19.000000     253.000000
# 50%      12.300000    23.000000     283.000000
# ...

# %%
emission_df.count()
# Out:
# MODEL                679
# MAKE                 679
# MODEL.1              679
# VEHICLE CLASS        679
# ENGINE_SIZE          679
# CYLINDERS            679
# TRANSMISSION         679
# FUEL                 679
# FUEL_CONSUMPTION*    679
# Unnamed: 9           679
# Unnamed: 10          679
# Unnamed: 11          679
# CO2_EMISSIONS        679
# dtype: int64

# %%
import jovian

# %%
jovian.commit()
# Out:
# [jovian] Updating notebook "umeshnandargi2000/zerotopandas-course-project-starter" on https://jovian.ai
# [jovian] Committed successfully! https://jovian.ai/umeshnandargi2000/zerotopandas-course-project-starter
# 'https://jovian.ai/umeshnandargi2000/zerotopandas-course-project-starter'

# %% [markdown]
# ## Exploratory Analysis and Visualization
#
# **Exploring the CO2 Emission data Of vehicles from Canada in the year 2001**

# %%
emission_df
# Out:
#      MODEL   MAKE              MODEL.1             VEHICLE CLASS  ENGINE_SIZE  \
# 0     2001  ACURA                1.7EL                   COMPACT          1.7
# 1     2001  ACURA                1.7EL                   COMPACT          1.7
# 2     2001  ACURA                3.2CL                   COMPACT          3.2
# 3     2001  ACURA                3.2TL                  MID-SIZE          3.2
# 4     2001  ACURA                3.5RL                  MID-SIZE          3.5
# ..     ...    ...                  ...                       ...          ...
# 674   2001  VOLVO   V70 T5 WAGON TURBO  STATION WAGON - MID-SIZE          2.3
# 675   2001  VOLVO            V70 WAGON  STATION WAGON - MID-SIZE          2.4
# 676   2001  VOLVO            V70 WAGON  STATION WAGON - MID-SIZE          2.4
# 677   2001  VOLVO  V70 WAGON AWD TURBO  STATION WAGON - MID-SIZE          2.4
# 678   2001  VOLVO     V70 XC AWD TURBO                       SUV          2.4
#
# ...

# %%
(f'The average CO2 emission of vehicles is {emission_df.CO2_EMISSIONS.mean()}')
# Out:
# 'The average CO2 emission of vehicles is 293.65684830633285'

# %%
maxemission_df = emission_df.sort_values('CO2_EMISSIONS' , ascending=False).head(5)[['MAKE','MODEL.1', 'CO2_EMISSIONS','FUEL_CONSUMPTION*']].reset_index()
maxemission_df
# Out:
#    index     MAKE             MODEL.1  CO2_EMISSIONS  FUEL_CONSUMPTION*
# 0    316      GMC    K1500 SIERRA 4X4            478               23.2
# 1    319      GMC     K1500 YUKON 4X4            453               22.4
# 2    321      GMC  K1500 YUKON XL 4X4            453               22.4
# 3    411  LINCOLN       NAVIGATOR 4X4            449               22.4
# 4    214    DODGE        RAM 1500 4X4            439               22.1

# %%
print(f'''The vehicle {maxemission_df.at[0, 'MAKE']} {maxemission_df.at[0, 'MODEL.1']} is the most polluting vehicle ''')
# Out:
# The vehicle GMC K1500 SIERRA 4X4 is the most polluting vehicle

# %% [markdown]
# Let's begin by importing`matplotlib.pyplot` and `seaborn`.

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (12, 9)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %%
emission_df['VEHICLE CLASS'].describe()
# Out:
# count         679
# unique         14
# top       COMPACT
# freq          145
# Name: VEHICLE CLASS, dtype: object

# %% [markdown]
# # **Exploring the relationship between CO2 Emissions and Engine Size of vehicles**

# %%
plt.figure(figsize=(18, 6))

sns.scatterplot(x= emission_df.ENGINE_SIZE, y= emission_df.CO2_EMISSIONS, hue =emission_df['VEHICLE CLASS']);
plt.title('Engine Size vs CO2 Emissions');

# %% [markdown]
# The above scatter plot shows the relationship between CO2 Emissions and Engine Size of vehicles for different vehicle classes

# %% [markdown]
# # **Exploring the dataset of top 5 vehicles that cause the CO2 emissions**

# %%
maxemission_df
# Out:
#    index     MAKE             MODEL.1  CO2_EMISSIONS  FUEL_CONSUMPTION*
# 0    316      GMC    K1500 SIERRA 4X4            478               23.2
# 1    319      GMC     K1500 YUKON 4X4            453               22.4
# 2    321      GMC  K1500 YUKON XL 4X4            453               22.4
# 3    411  LINCOLN       NAVIGATOR 4X4            449               22.4
# 4    214    DODGE        RAM 1500 4X4            439               22.1

# %%
sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (17, 15)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

sns.barplot(x= 'MAKE', y = 'CO2_EMISSIONS' , hue ='MODEL.1', data=maxemission_df);
plt.title('Top 5 vehicles causing CO2 emissions');

# %% [markdown]
# From the above Bar graph it is clear that the **GMC K1500 SIERRA 4X4** has the maximum CO2 emission

# %% [markdown]
# # **Exploring the fuel consumption distribution of VOLVO cars using Histogram**

# %%
emission_df
# Out:
#      MODEL   MAKE              MODEL.1             VEHICLE CLASS  ENGINE_SIZE  \
# 0     2001  ACURA                1.7EL                   COMPACT          1.7
# 1     2001  ACURA                1.7EL                   COMPACT          1.7
# 2     2001  ACURA                3.2CL                   COMPACT          3.2
# 3     2001  ACURA                3.2TL                  MID-SIZE          3.2
# 4     2001  ACURA                3.5RL                  MID-SIZE          3.5
# ..     ...    ...                  ...                       ...          ...
# 674   2001  VOLVO   V70 T5 WAGON TURBO  STATION WAGON - MID-SIZE          2.3
# 675   2001  VOLVO            V70 WAGON  STATION WAGON - MID-SIZE          2.4
# 676   2001  VOLVO            V70 WAGON  STATION WAGON - MID-SIZE          2.4
# 677   2001  VOLVO  V70 WAGON AWD TURBO  STATION WAGON - MID-SIZE          2.4
# 678   2001  VOLVO     V70 XC AWD TURBO                       SUV          2.4
#
# ...

# %%
volvo_df = emission_df[emission_df.MAKE == 'VOLVO']
volvo_df
# Out:
#      MODEL   MAKE                      MODEL.1             VEHICLE CLASS  \
# 655   2001  VOLVO        C70 CONVERTIBLE TURBO                SUBCOMPACT
# 656   2001  VOLVO        C70 CONVERTIBLE TURBO                SUBCOMPACT
# 657   2001  VOLVO        C70 CONVERTIBLE TURBO                SUBCOMPACT
# 658   2001  VOLVO                    C70 TURBO                   COMPACT
# 659   2001  VOLVO                    C70 TURBO                   COMPACT
# 660   2001  VOLVO                    C70 TURBO                   COMPACT
# 661   2001  VOLVO                    S40 TURBO                   COMPACT
# 662   2001  VOLVO                          S60                   COMPACT
# 663   2001  VOLVO                          S60                   COMPACT
# 664   2001  VOLVO               S60 2.4T TURBO                   COMPACT
# 665   2001  VOLVO               S60 2.4T TURBO                   COMPACT
# 666   2001  VOLVO                 S60 T5 TURBO                   COMPACT
# ...

# %%
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (10, 7)
matplotlib.rcParams['figure.facecolor'] = '#00000000'
sns.histplot(volvo_df['FUEL_CONSUMPTION*'] , bins =5);
plt.title('fuel consumption distribution of VOLVO cars');

# %% [markdown]
# From the above Histogram it is observed that there are around **11** cars having Fuel Consumption of **12.5 to 13.1**

# %% [markdown]
# # **Exploring the relationship between Number of cylinder in a particular MAKE and the corresponding Fuel Consumption**

# %%
emission_df
# Out:
#      MODEL   MAKE              MODEL.1             VEHICLE CLASS  ENGINE_SIZE  \
# 0     2001  ACURA                1.7EL                   COMPACT          1.7
# 1     2001  ACURA                1.7EL                   COMPACT          1.7
# 2     2001  ACURA                3.2CL                   COMPACT          3.2
# 3     2001  ACURA                3.2TL                  MID-SIZE          3.2
# 4     2001  ACURA                3.5RL                  MID-SIZE          3.5
# ..     ...    ...                  ...                       ...          ...
# 674   2001  VOLVO   V70 T5 WAGON TURBO  STATION WAGON - MID-SIZE          2.3
# 675   2001  VOLVO            V70 WAGON  STATION WAGON - MID-SIZE          2.4
# 676   2001  VOLVO            V70 WAGON  STATION WAGON - MID-SIZE          2.4
# 677   2001  VOLVO  V70 WAGON AWD TURBO  STATION WAGON - MID-SIZE          2.4
# 678   2001  VOLVO     V70 XC AWD TURBO                       SUV          2.4
#
# ...

# %%
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (17, 15)
matplotlib.rcParams['figure.facecolor'] = '#00000000'
sns.scatterplot(x= emission_df.CYLINDERS, y= emission_df['FUEL_CONSUMPTION*'], hue = emission_df.MAKE);
plt.title('No. of Cylinders vs Fuel Consumption');

# %% [markdown]
# Let us save and upload our work to Jovian before continuing

# %%
import jovian

# %%
jovian.commit()
# Out:
# [jovian] Updating notebook "umeshnandargi2000/zerotopandas-course-project-starter" on https://jovian.ai
# [jovian] Committed successfully! https://jovian.ai/umeshnandargi2000/zerotopandas-course-project-starter
# 'https://jovian.ai/umeshnandargi2000/zerotopandas-course-project-starter'

# %% [markdown]
# ## Asking and Answering Questions
#
# TODO - write some explanation here.

# %%
emission_df
# Out:
#      MODEL   MAKE              MODEL.1             VEHICLE CLASS  ENGINE_SIZE  \
# 0     2001  ACURA                1.7EL                   COMPACT          1.7
# 1     2001  ACURA                1.7EL                   COMPACT          1.7
# 2     2001  ACURA                3.2CL                   COMPACT          3.2
# 3     2001  ACURA                3.2TL                  MID-SIZE          3.2
# 4     2001  ACURA                3.5RL                  MID-SIZE          3.5
# ..     ...    ...                  ...                       ...          ...
# 674   2001  VOLVO   V70 T5 WAGON TURBO  STATION WAGON - MID-SIZE          2.3
# 675   2001  VOLVO            V70 WAGON  STATION WAGON - MID-SIZE          2.4
# 676   2001  VOLVO            V70 WAGON  STATION WAGON - MID-SIZE          2.4
# 677   2001  VOLVO  V70 WAGON AWD TURBO  STATION WAGON - MID-SIZE          2.4
# 678   2001  VOLVO     V70 XC AWD TURBO                       SUV          2.4
#
# ...

# %% [markdown]
# #### Q1: Create a dataframe containing top 10 vehicles with the most CO2 Emission and find the vehicle with most amount of CO2 emission

# %%
max_emission_df= emission_df.sort_values('CO2_EMISSIONS' , ascending=False).head(10)

# %%
max_emission_df
# Out:
#      MODEL     MAKE             MODEL.1            VEHICLE CLASS  ENGINE_SIZE  \
# 316   2001      GMC    K1500 SIERRA 4X4  PICKUP TRUCK - STANDARD          6.0
# 319   2001      GMC     K1500 YUKON 4X4                      SUV          6.0
# 321   2001      GMC  K1500 YUKON XL 4X4                      SUV          6.0
# 411   2001  LINCOLN       NAVIGATOR 4X4                      SUV          5.4
# 214   2001    DODGE        RAM 1500 4X4  PICKUP TRUCK - STANDARD          5.2
# 213   2001    DODGE        RAM 1500 4X4  PICKUP TRUCK - STANDARD          5.2
# 225   2001    DODGE      RAM 2500 WAGON          VAN - PASSENGER          5.2
# 195   2001    DODGE          DAKOTA 4X4  PICKUP TRUCK - STANDARD          5.9
# 241   2001     FORD            E250 VAN              VAN - CARGO          5.4
# 194   2001    DODGE          DAKOTA 4X4  PICKUP TRUCK - STANDARD          5.9
#
#      CYLINDERS TRANSMISSION FUEL  FUEL_CONSUMPTION*  Unnamed: 9  Unnamed: 10  \
# ...

# %% [markdown]
# ### **The vehicle GMC K1500 SIERRA 4X4 has the maximum amount of CO2 Emission**

# %% [markdown]
# #### Q2:How many vehicles have above average CO2 emissions?

# %%
avg_emission_df = emission_df[emission_df.CO2_EMISSIONS > emission_df.CO2_EMISSIONS.mean()]
avg_emission_df
# Out:
#      MODEL        MAKE               MODEL.1             VEHICLE CLASS  \
# 4     2001       ACURA                 3.5RL                  MID-SIZE
# 8     2001       ACURA                   MDX                       SUV
# 9     2001       ACURA                   NSX                TWO-SEATER
# 10    2001       ACURA                   NSX                TWO-SEATER
# 18    2001        AUDI                    A6                  MID-SIZE
# ..     ...         ...                   ...                       ...
# 618   2001      TOYOTA            TUNDRA 4X4   PICKUP TRUCK - STANDARD
# 619   2001      TOYOTA            TUNDRA 4X4   PICKUP TRUCK - STANDARD
# 649   2001  VOLKSWAGEN        PASSAT 4MOTION                   COMPACT
# 650   2001  VOLKSWAGEN  PASSAT 4MOTION WAGON  STATION WAGON - MID-SIZE
# 678   2001       VOLVO      V70 XC AWD TURBO                       SUV
#
#      ENGINE_SIZE  CYLINDERS TRANSMISSION FUEL  FUEL_CONSUMPTION*  Unnamed: 9  \
# ...

# %%
print(avg_emission_df.CO2_EMISSIONS.count())
# Out:
# 307

# %% [markdown]
# ### **There are 307 vehicles having CO2 Emissions above average**

# %% [markdown]
# #### Q3: Count the total number of VOLKSWAGEN Models

# %%
make_df = emission_df.groupby('MAKE').count().reset_index()
make_df
# Out:
#              MAKE  MODEL  MODEL.1  VEHICLE CLASS  ENGINE_SIZE  CYLINDERS  \
# 0           ACURA     11       11             11           11         11
# 1            AUDI     24       24             24           24         24
# 2             BMW     43       43             43           43         43
# 3           BUICK      6        6              6            6          6
# 4        CADILLAC      4        4              4            4          4
# 5       CHEVROLET     60       60             60           60         60
# 6        CHRYSLER     25       25             25           25         25
# 7          DAEWOO     10       10             10           10         10
# 8           DODGE     47       47             47           47         47
# 9            FORD     63       63             63           63         63
# 10            GMC     41       41             41           41         41
# 11          HONDA     14       14             14           14         14
# ...

# %%
make_df.at[32, 'MODEL.1']
# Out:
# 35

# %% [markdown]
# ### **There are 35 VOLKSWAGEN Models in the dataframe**

# %% [markdown]
# #### Q4: Create a dataframe containing top 5 vehicles with the highest Fuel Consumption and find out which Vehicle has the maximum fuel Consumption

# %%
fuel_consumption_df = emission_df.sort_values('FUEL_CONSUMPTION*', ascending = False).head(10).reset_index()

# %%
fuel_consumption_df
# Out:
#    index  MODEL     MAKE             MODEL.1            VEHICLE CLASS  \
# 0    316   2001      GMC    K1500 SIERRA 4X4  PICKUP TRUCK - STANDARD
# 1    228   2001    DODGE           VIPER GTS               TWO-SEATER
# 2    229   2001    DODGE         VIPER RT/10               TWO-SEATER
# 3    321   2001      GMC  K1500 YUKON XL 4X4                      SUV
# 4    411   2001  LINCOLN       NAVIGATOR 4X4                      SUV
# 5    319   2001      GMC     K1500 YUKON 4X4                      SUV
# 6    242   2001     FORD        E250 VAN NGV              VAN - CARGO
# 7    214   2001    DODGE        RAM 1500 4X4  PICKUP TRUCK - STANDARD
# 8    195   2001    DODGE          DAKOTA 4X4  PICKUP TRUCK - STANDARD
# 9    213   2001    DODGE        RAM 1500 4X4  PICKUP TRUCK - STANDARD
#
#    ENGINE_SIZE  CYLINDERS TRANSMISSION FUEL  FUEL_CONSUMPTION*  Unnamed: 9  \
# 0          6.0          8           A4    X               23.2        18.0
# ...

# %%
print(fuel_consumption_df.at[0, 'MAKE'], fuel_consumption_df.at[0, 'MODEL.1'])
# Out:
# GMC K1500 SIERRA 4X4

# %% [markdown]
# ### **The Vehicle has the maximum fuel Consumption is GMC K1500 SIERRA 4X4**

# %% [markdown]
# #### Q5: What is the most common vehicle class in the data frame

# %%
class_df = emission_df.groupby('VEHICLE CLASS').count().sort_values('MODEL', ascending=False).reset_index()
class_df
# Out:
#                VEHICLE CLASS  MODEL  MAKE  MODEL.1  ENGINE_SIZE  CYLINDERS  \
# 0                    COMPACT    145   145      145          145        145
# 1    PICKUP TRUCK - STANDARD    101   101      101          101        101
# 2                        SUV     98    98       98           98         98
# 3                   MID-SIZE     82    82       82           82         82
# 4                 SUBCOMPACT     62    62       62           62         62
# 5   STATION WAGON - MID-SIZE     31    31       31           31         31
# 6                 TWO-SEATER     31    31       31           31         31
# 7                  FULL-SIZE     30    30       30           30         30
# 8                VAN - CARGO     23    23       23           23         23
# 9            VAN - PASSENGER     18    18       18           18         18
# 10               MINICOMPACT     17    17       17           17         17
# ...

# %%
class_df.at[0, 'VEHICLE CLASS']
# Out:
# 'COMPACT'

# %% [markdown]
#  ### **The vehicle class *COMPACT* is the most common vehicle class in the data frame**

# %% [markdown]
# Let us save and upload our work to Jovian before continuing.

# %%
import jovian

# %%
jovian.commit()
# Out:
# [jovian] Updating notebook "umeshnandargi2000/zerotopandas-course-project-starter" on https://jovian.ai
# [jovian] Committed successfully! https://jovian.ai/umeshnandargi2000/zerotopandas-course-project-starter
# 'https://jovian.ai/umeshnandargi2000/zerotopandas-course-project-starter'

# %% [markdown]
# ## Inferences and Conclusion
#
# In the given data analysis Following conclusions were made:
# #### The average CO2 emission of vehicles is 293.65684830633285
# #### The vehicle class COMPACT is the most common vehicle class in the data frame
# #### The Vehicle GMC K1500 SIERRA 4X4 has the maximum fuel Consumption as well as maximum amount of CO2 Emission
# #### There are 307 vehicles having CO2 Emissions above the average value
# #### From the Histogram plotted, it is observed that there are around **11** cars having Fuel Consumption in the range **12.5 to 13.1**

# %%
import jovian

# %%
jovian.commit()
